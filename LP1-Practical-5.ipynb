# %%
# label Encoding is used when the input variable is of string type or categorical data
# We have to do binarization of output variable

# %%
 import pandas as pd
 import seaborn as sns

# %%
df = pd.read_csv('Admission_Predict.csv')

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.shape
# Out:
# (400, 9)

# %%
# Decision tree is a type of explicit feature selection algorithm
# The mathematical model of decision tree is made such that it decides 
# which feature is important or not

# %%
 df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
from sklearn.preprocessing import Binarizer
bi = Binarizer(threshold=0.75)
df['Chance of Admit '] = bi.fit_transform(df[['Chance of Admit ']])

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1               1.0
# 1         1               1.0
# 2         1               0.0
# 3         1               1.0
# 4         0               0.0

# %%
x = df.drop('Chance of Admit ', axis = 1)
y = df['Chance of Admit ']

# %%
x
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research
# 0           1
# 1           1
# ...

# %%
y = y.astype('int')

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Chance of Admit , Length: 400, dtype: int32

# %%
sns.countplot(x = y)
# Out:
# <AxesSubplot:xlabel='Chance of Admit ', ylabel='count'>

# %%
y.value_counts()
# Out:
# 0    228
# 1    172
# Name: Chance of Admit , dtype: int64

# %%
# Cross_Validation 
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0 , test_size=0.25)

# %%
x_train.shape
# Out:
# (300, 8)

# %%
x_test.shape
# Out:
# (100, 8)

# %%
x_test
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 132         133        309          105                  5  3.5   3.5  8.56
# 309         310        308          110                  4  3.5   3.0  8.60
# 341         342        326          110                  3  3.5   3.5  8.76
# 196         197        306          105                  2  3.0   2.5  8.26
# 246         247        316          105                  3  3.0   3.5  8.73
# ..          ...        ...          ...                ...  ...   ...   ...
# 146         147        315          105                  3  2.0   2.5  8.48
# 135         136        314          109                  4  3.5   4.0  8.77
# 390         391        314          102                  2  2.0   2.5  8.24
# 264         265        325          110                  2  3.0   2.5  8.76
# 364         365        313          102                  3  3.5   4.0  8.90
#
#      Research
# 132         0
# 309         0
# ...

# %%
#import the class
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(random_state=0)

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
result = pd.DataFrame({
    'actual' : y_test,
    'predicted' : y_pred
})

# %%
result
# Out:
#      actual  predicted
# 132       0          0
# 309       0          0
# 341       1          1
# 196       0          0
# 246       0          1
# ..      ...        ...
# 146       0          0
# 135       1          1
# 390       0          0
# 264       0          0
# 364       1          1
#
# [100 rows x 2 columns]

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from sklearn.metrics import classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        59
#            1       0.88      0.88      0.88        41
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.90      0.90       100
# weighted avg       0.90      0.90      0.90       100

# %%
new = [[136,314,109,4,3.5,4.0,8.77,1]]
classifier.predict(new)[0]
# Out:
# C:\Users\saura\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 1

# %%
from sklearn.tree import plot_tree

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,12))
plot_tree(classifier, fontsize=8 , filled=True,rounded=True,
         feature_names=x.columns, class_names=['NA','AD']);

#class_names is given to leaf node
